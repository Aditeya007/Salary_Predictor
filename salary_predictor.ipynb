# %%
import numpy as np 
import pandas as pd
import  matplotlib.pyplot as plt 
import seaborn as sns

# %%
data=pd.read_csv(r"C:\DESKTOP_FILES\project\data\survey_results_public.csv")
data.head
# Out:
# <bound method NDFrame.head of        ResponseId                      MainBranch                 Age  \
# 0               1  I am a developer by profession  Under 18 years old
# 1               2  I am a developer by profession     35-44 years old
# 2               3  I am a developer by profession     45-54 years old
# 3               4           I am learning to code     18-24 years old
# 4               5  I am a developer by profession     18-24 years old
# ...           ...                             ...                 ...
# 65432       65433  I am a developer by profession     18-24 years old
# 65433       65434  I am a developer by profession     25-34 years old
# 65434       65435  I am a developer by profession     25-34 years old
# 65435       65436  I am a developer by profession     18-24 years old
# 65436       65437     I code primarily as a hobby     18-24 years old
#
#                 Employment                            RemoteWork   Check  \
# ...

# %%
data.shape , data.columns
# Out:
# ((65437, 114),
#  Index(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#         'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#         ...
#         'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#         'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#         'ConvertedCompYearly', 'JobSat'],
#        dtype='object', length=114))

# %%
for col in data.columns:
    print(col)
# Out:
# ResponseId
# MainBranch
# Age
# Employment
# RemoteWork
# Check
# CodingActivities
# EdLevel
# LearnCode
# LearnCodeOnline
# TechDoc
# YearsCode
# YearsCodePro
# DevType
# OrgSize
# PurchaseInfluence
# BuyNewTool
# BuildvsBuy
# TechEndorse
# Country
# Currency
# CompTotal
# LanguageHaveWorkedWith
# LanguageWantToWorkWith
# LanguageAdmired
# DatabaseHaveWorkedWith
# DatabaseWantToWorkWith
# DatabaseAdmired
# PlatformHaveWorkedWith
# PlatformWantToWorkWith
# PlatformAdmired
# WebframeHaveWorkedWith
# WebframeWantToWorkWith
# WebframeAdmired
# EmbeddedHaveWorkedWith
# EmbeddedWantToWorkWith
# EmbeddedAdmired
# MiscTechHaveWorkedWith
# MiscTechWantToWorkWith
# MiscTechAdmired
# ToolsTechHaveWorkedWith
# ToolsTechWantToWorkWith
# ToolsTechAdmired
# NEWCollabToolsHaveWorkedWith
# NEWCollabToolsWantToWorkWith
# NEWCollabToolsAdmired
# OpSysPersonal use
# OpSysProfessional use
# OfficeStackAsyncHaveWorkedWith
# OfficeStackAsyncWantToWorkWith
# OfficeStackAsyncAdmired
# ...

# %%
data = data[
[
"Country",
"EdLevel",
"YearsCodePro",
"DevType",
"OrgSize",
"Industry",
"ConvertedCompYearly"
]
]
data.head()
# Out:
#                                              Country  \
# 0                           United States of America
# 1  United Kingdom of Great Britain and Northern I...
# 2  United Kingdom of Great Britain and Northern I...
# 3                                             Canada
# 4                                             Norway
#
#                                              EdLevel YearsCodePro  \
# 0                          Primary/elementary school          NaN
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)           17
# 2    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)           27
# 3  Some college/university study without earning ...          NaN
# 4  Secondary school (e.g. American high school, G...          NaN
#
#                  DevType OrgSize Industry  ConvertedCompYearly
# 0                    NaN     NaN      NaN                  NaN
# 1  Developer, full-stack     NaN      NaN                  NaN
# ...

# %%
data = data.rename({"ConvertedCompYearly": "Salary"}, axis=1)
data.head()
# Out:
#                                              Country  \
# 0                           United States of America
# 1  United Kingdom of Great Britain and Northern I...
# 2  United Kingdom of Great Britain and Northern I...
# 3                                             Canada
# 4                                             Norway
#
#                                              EdLevel YearsCodePro  \
# 0                          Primary/elementary school          NaN
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)           17
# 2    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)           27
# 3  Some college/university study without earning ...          NaN
# 4  Secondary school (e.g. American high school, G...          NaN
#
#                  DevType OrgSize Industry  Salary
# 0                    NaN     NaN      NaN     NaN
# 1  Developer, full-stack     NaN      NaN     NaN
# 2   Developer Experience     NaN      NaN     NaN
# ...

# %%
data.isnull().sum()
# Out:
# Country          6507
# EdLevel          4653
# YearsCodePro    13827
# DevType          5992
# OrgSize         17957
# Industry        36579
# Salary          42002
# dtype: int64

# %%
data = data.dropna(subset=["Salary"])
data.shape
# Out:
# (23435, 7)

# %%
# Out:
# (23435, 7)

# %%
data
# Out:
#                         Country  \
# 72                     Pakistan
# 374                     Austria
# 379                      Turkey
# 385                      France
# 389    United States of America
# ...                         ...
# 41180                    Sweden
# 41184  United States of America
# 41185  United States of America
# 41186  United States of America
# 41187               Switzerland
#
#                                                  EdLevel YearsCodePro  \
# 72     Secondary school (e.g. American high school, G...            1
# 374       Professional degree (JD, MD, Ph.D, Ed.D, etc.)            6
# 379      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)            6
# 385      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)           17
# 389    Some college/university study without earning ...            7
# ...                                                  ...          ...
# 41180    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)            3
# ...

# %%
data["YearsCodePro"].dtype , data.columns.dtype
# Out:
# (dtype('O'), dtype('O'))

# %%
data["YearsCodePro"].unique()
# Out:
# array(['1', '6', '17', '7', '18', '25', '30', '20', '50', '27', '16', '4',
#        '15', '11', '23', '10', '9', '8', '24', '12', '26', '40',
#        'Less than 1 year', '14', '22', '5', '28', '3', '44', '42', '13',
#        '19', '2', '35', '31', '41', '36', nan, '38', '32', '34', '21',
#        'More than 50 years', '29', '45', '43', '37', '33', '48', '39',
#        '46', '49', '47'], dtype=object)

# %%
def clean_experience(x):
    if x == "More than 50 years":
        return 50
    if x == "Less than 1 year":
        return 0.5
    return float(x)
data["YearsCodePro"] = data["YearsCodePro"].apply(clean_experience)

# %%
data.isnull().sum()
# Out:
# Country            0
# EdLevel            0
# YearsCodePro      90
# DevType           32
# OrgSize           25
# Industry        7459
# Salary             0
# dtype: int64

# %%
data=data.dropna()
data.isnull().sum()
# Out:
# Country         0
# EdLevel         0
# YearsCodePro    0
# DevType         0
# OrgSize         0
# Industry        0
# Salary          0
# dtype: int64

# %%
data.shape
# Out:
# (15922, 7)

# %%
data.dtypes
# Out:
# Country          object
# EdLevel          object
# YearsCodePro    float64
# DevType          object
# OrgSize          object
# Industry         object
# Salary          float64
# dtype: object

# %%
data.columns.unique()
# Out:
# Index(['Country', 'EdLevel', 'YearsCodePro', 'DevType', 'OrgSize', 'Industry',
#        'Salary'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Country         0
# EdLevel         0
# YearsCodePro    0
# DevType         0
# OrgSize         0
# Industry        0
# Salary          0
# dtype: int64
